# %%
import pandas as pd

# %%
df = pd.read_csv("https://media.geeksforgeeks.org/wp-content/uploads/nba.csv")

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
s = df['Name'][0:11]

# %%
# HOW TO SET NAMED INDEX INSTEAD OF DEFAULT INDEX TO ANY SERIES SEE

pd.Series(list(s),['a','b','c','d','e','f','g','a','i','j','k'])
# Out:
# a      Avery Bradley
# b        Jae Crowder
# c       John Holland
# d        R.J. Hunter
# e      Jonas Jerebko
# f       Amir Johnson
# g      Jordan Mickey
# a       Kelly Olynyk
# i       Terry Rozier
# j       Marcus Smart
# k    Jared Sullinger
# dtype: object

# %%
n = df['Number'][0:10]

# %%
n
# Out:
# 0     0.0
# 1    99.0
# 2    30.0
# 3    28.0
# 4     8.0
# 5    90.0
# 6    55.0
# 7    41.0
# 8    12.0
# 9    36.0
# Name: Number, dtype: float64

# %%
a = df['Age'][0:10]

# %%
a
# Out:
# 0    25.0
# 1    25.0
# 2    27.0
# 3    22.0
# 4    29.0
# 5    29.0
# 6    21.0
# 7    25.0
# 8    22.0
# 9    22.0
# Name: Age, dtype: float64

# %%
# koi bhi operation on the basis of indexes hota hai agar dono ke pass same index hai tabhi,
# operation hoga wrna corresponding value nall show krega

a+n
# Out:
# 0     25.0
# 1    124.0
# 2     57.0
# 3     50.0
# 4     37.0
# 5    119.0
# 6     76.0
# 7     66.0
# 8     34.0
# 9     58.0
# dtype: float64

# %%
# how to delete any column it will not do permanently

df.drop("Name", axis=1)
# Out:
#                Team  Number Position   Age Height  Weight            College  \
# 0    Boston Celtics     0.0       PG  25.0    6-2   180.0              Texas
# 1    Boston Celtics    99.0       SF  25.0    6-6   235.0          Marquette
# 2    Boston Celtics    30.0       SG  27.0    6-5   205.0  Boston University
# 3    Boston Celtics    28.0       SG  22.0    6-5   185.0      Georgia State
# 4    Boston Celtics     8.0       PF  29.0   6-10   231.0                NaN
# ..              ...     ...      ...   ...    ...     ...                ...
# 453       Utah Jazz     8.0       PG  26.0    6-3   203.0             Butler
# 454       Utah Jazz    25.0       PG  24.0    6-1   179.0                NaN
# 455       Utah Jazz    21.0        C  26.0    7-3   256.0                NaN
# 456       Utah Jazz    24.0        C  26.0    7-0   231.0             Kansas
# 457             NaN     NaN      NaN   NaN    NaN     NaN                NaN
#
#         Salary
# 0    7730337.0
# ...

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
# for permanently deletion of any column

#  axis bole to x and y axis ki value for row bydefault axis==0 and for column axis == 1

df.drop('Name',axis=1,inplace=True)

# %%
df
# Out:
#                Team  Number Position   Age Height  Weight            College  \
# 0    Boston Celtics     0.0       PG  25.0    6-2   180.0              Texas
# 1    Boston Celtics    99.0       SF  25.0    6-6   235.0          Marquette
# 2    Boston Celtics    30.0       SG  27.0    6-5   205.0  Boston University
# 3    Boston Celtics    28.0       SG  22.0    6-5   185.0      Georgia State
# 4    Boston Celtics     8.0       PF  29.0   6-10   231.0                NaN
# ..              ...     ...      ...   ...    ...     ...                ...
# 453       Utah Jazz     8.0       PG  26.0    6-3   203.0             Butler
# 454       Utah Jazz    25.0       PG  24.0    6-1   179.0                NaN
# 455       Utah Jazz    21.0        C  26.0    7-3   256.0                NaN
# 456       Utah Jazz    24.0        C  26.0    7-0   231.0             Kansas
# 457             NaN     NaN      NaN   NaN    NaN     NaN                NaN
#
#         Salary
# 0    7730337.0
# ...

# %%
# for row deletion 
df.drop(1)
# Out:
#                Team  Number Position   Age Height  Weight            College  \
# 0    Boston Celtics     0.0       PG  25.0    6-2   180.0              Texas
# 2    Boston Celtics    30.0       SG  27.0    6-5   205.0  Boston University
# 3    Boston Celtics    28.0       SG  22.0    6-5   185.0      Georgia State
# 4    Boston Celtics     8.0       PF  29.0   6-10   231.0                NaN
# 5    Boston Celtics    90.0       PF  29.0    6-9   240.0                NaN
# ..              ...     ...      ...   ...    ...     ...                ...
# 453       Utah Jazz     8.0       PG  26.0    6-3   203.0             Butler
# 454       Utah Jazz    25.0       PG  24.0    6-1   179.0                NaN
# 455       Utah Jazz    21.0        C  26.0    7-3   256.0                NaN
# 456       Utah Jazz    24.0        C  26.0    7-0   231.0             Kansas
# 457             NaN     NaN      NaN   NaN    NaN     NaN                NaN
#
#          Salary
# 0     7730337.0
# ...

# %%
# for permanent deletion of row do this

df.drop(1,inplace=True)

# %%
df
# Out:
#                Team  Number Position   Age Height  Weight            College  \
# 0    Boston Celtics     0.0       PG  25.0    6-2   180.0              Texas
# 2    Boston Celtics    30.0       SG  27.0    6-5   205.0  Boston University
# 3    Boston Celtics    28.0       SG  22.0    6-5   185.0      Georgia State
# 4    Boston Celtics     8.0       PF  29.0   6-10   231.0                NaN
# 5    Boston Celtics    90.0       PF  29.0    6-9   240.0                NaN
# ..              ...     ...      ...   ...    ...     ...                ...
# 453       Utah Jazz     8.0       PG  26.0    6-3   203.0             Butler
# 454       Utah Jazz    25.0       PG  24.0    6-1   179.0                NaN
# 455       Utah Jazz    21.0        C  26.0    7-3   256.0                NaN
# 456       Utah Jazz    24.0        C  26.0    7-0   231.0             Kansas
# 457             NaN     NaN      NaN   NaN    NaN     NaN                NaN
#
#          Salary
# 0     7730337.0
# ...

# %%
# how to make any column as a index of dataframe see

df.set_index('Name',inplace = True)

# %%
df
# Out:
#                          Team  Number Position   Age Height  Weight  \
# Name
# Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# Jae Crowder    Boston Celtics    99.0       SF  25.0    6-6   235.0
# John Holland   Boston Celtics    30.0       SG  27.0    6-5   205.0
# R.J. Hunter    Boston Celtics    28.0       SG  22.0    6-5   185.0
# Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ...                       ...     ...      ...   ...    ...     ...
# Shelvin Mack        Utah Jazz     8.0       PG  26.0    6-3   203.0
# Raul Neto           Utah Jazz    25.0       PG  24.0    6-1   179.0
# Tibor Pleiss        Utah Jazz    21.0        C  26.0    7-3   256.0
# Jeff Withey         Utah Jazz    24.0        C  26.0    7-0   231.0
# NaN                       NaN     NaN      NaN   NaN    NaN     NaN
#
#                          College     Salary
# Name
# Avery Bradley              Texas  7730337.0
# Jae Crowder            Marquette  6796117.0
# ...

# %%
# it reset all changes in dataframe and get original dataframe

df.reset_index()
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
# it will remove those rows which have any NaN values seee

df.dropna()
# Out:
#                          Team  Number Position   Age Height  Weight  \
# Name
# Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# Jae Crowder    Boston Celtics    99.0       SF  25.0    6-6   235.0
# R.J. Hunter    Boston Celtics    28.0       SG  22.0    6-5   185.0
# Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# Kelly Olynyk   Boston Celtics    41.0        C  25.0    7-0   238.0
# ...                       ...     ...      ...   ...    ...     ...
# Rodney Hood         Utah Jazz     5.0       SG  23.0    6-8   206.0
# Chris Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# Trey Lyles          Utah Jazz    41.0       PF  20.0   6-10   234.0
# Shelvin Mack        Utah Jazz     8.0       PG  26.0    6-3   203.0
# Jeff Withey         Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                      College     Salary
# Name
# Avery Bradley          Texas  7730337.0
# Jae Crowder        Marquette  6796117.0
# ...

# %%
# it will remove those column which have any NaN value see

df.dropna(axis=1)
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
# if we want to set any value instead of all NaN PLACES SEE

df.fillna("sanit")
# Out:
#                          Team Number Position    Age Height Weight  \
# Name
# Avery Bradley  Boston Celtics    0.0       PG   25.0    6-2  180.0
# Jae Crowder    Boston Celtics   99.0       SF   25.0    6-6  235.0
# John Holland   Boston Celtics   30.0       SG   27.0    6-5  205.0
# R.J. Hunter    Boston Celtics   28.0       SG   22.0    6-5  185.0
# Jonas Jerebko  Boston Celtics    8.0       PF   29.0   6-10  231.0
# ...                       ...    ...      ...    ...    ...    ...
# Shelvin Mack        Utah Jazz    8.0       PG   26.0    6-3  203.0
# Raul Neto           Utah Jazz   25.0       PG   24.0    6-1  179.0
# Tibor Pleiss        Utah Jazz   21.0        C   26.0    7-3  256.0
# Jeff Withey         Utah Jazz   24.0        C   26.0    7-0  231.0
# NaN                     sanit  sanit    sanit  sanit  sanit  sanit
#
#                          College     Salary
# Name
# Avery Bradley              Texas  7730337.0
# Jae Crowder            Marquette  6796117.0
# ...

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
# when we want group data on the basis of unique value of any column see

h = df.groupby("Height")

# %%
h.sum()
# Out:
# /tmp/ipykernel_2638/497127925.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   h.sum()
#         Number     Age   Weight       Salary
# Height
# 5-11      35.0    76.0    545.0    1767466.0
# 5-9        4.0    27.0    185.0    6912869.0
# 6-0       44.0   292.0   1835.0   57840753.0
# 6-1      241.0   427.0   2892.0   83486703.0
# 6-10     956.0  1291.0  11509.0  234027240.0
# 6-11     742.0  1095.0   9890.0  261775894.0
# 6-2      206.0   435.0   2966.0   46695068.0
# 6-3      357.0   937.0   6355.0  182433510.0
# 6-4      393.0   759.0   5914.0  134738716.0
# 6-5      362.0   814.0   6519.0  135694466.0
# 6-6      617.0  1100.0   8870.0  145803480.0
# 6-7      886.0  1215.0   9784.0  152855386.0
# 6-8      916.0  1151.0   9806.0  255867729.0
# 6-9     1321.0  1606.0  13804.0  235624069.0
# ...

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
# the way to concatenate two dataframe see

a = df[['Name','Team']][0:5]
a
# Out:
#             Name            Team
# 0  Avery Bradley  Boston Celtics
# 1    Jae Crowder  Boston Celtics
# 2   John Holland  Boston Celtics
# 3    R.J. Hunter  Boston Celtics
# 4  Jonas Jerebko  Boston Celtics

# %%
b = df[['Age','Number']][0:5]
b
# Out:
#     Age  Number
# 0  25.0     0.0
# 1  25.0    99.0
# 2  27.0    30.0
# 3  22.0    28.0
# 4  29.0     8.0

# %%
# axis=1 mtlb columnwise krna hai aur agar axis mentioned nhi hai to kaam 
# row wise hoga

pd.concat([a,b],axis = 1)
# Out:
#             Name            Team   Age  Number
# 0  Avery Bradley  Boston Celtics  25.0     0.0
# 1    Jae Crowder  Boston Celtics  25.0    99.0
# 2   John Holland  Boston Celtics  27.0    30.0
# 3    R.J. Hunter  Boston Celtics  22.0    28.0
# 4  Jonas Jerebko  Boston Celtics  29.0     8.0

# %%
pd.concat([a,b])
# Out:
#             Name            Team   Age  Number
# 0  Avery Bradley  Boston Celtics   NaN     NaN
# 1    Jae Crowder  Boston Celtics   NaN     NaN
# 2   John Holland  Boston Celtics   NaN     NaN
# 3    R.J. Hunter  Boston Celtics   NaN     NaN
# 4  Jonas Jerebko  Boston Celtics   NaN     NaN
# 0            NaN             NaN  25.0     0.0
# 1            NaN             NaN  25.0    99.0
# 2            NaN             NaN  27.0    30.0
# 3            NaN             NaN  22.0    28.0
# 4            NaN             NaN  29.0     8.0

# %%
data1 = pd.DataFrame({'key1':[1,2,3,4,5],
         'key2':[4,5,6,7,8],
         'key3':[3,4,5,6,6]})

# %%
data1
# Out:
#    key1  key2  key3
# 0     1     4     3
# 1     2     5     4
# 2     3     6     5
# 3     4     7     6
# 4     5     8     6

# %%
data2 = pd.DataFrame({'key1':[1,2,45,4,67],
         'key4':[56,5,6,7,8],
         'key5':[3,56,5,6,6]})

# %%
data2
# Out:
#    key1  key4  key5
# 0     1    56     3
# 1     2     5    56
# 2    45     6     5
# 3     4     7     6
# 4    67     8     6

# %%
pd.merge(data1,data2)
# Out:
#    key1  key2  key3  key4  key5
# 0     1     4     3    56     3
# 1     2     5     4     5    56
# 2     4     7     6     7     6

# %%
pd.merge(data1,data2,how='left')
# Out:
#    key1  key2  key3  key4  key5
# 0     1     4     3  56.0   3.0
# 1     2     5     4   5.0  56.0
# 2     3     6     5   NaN   NaN
# 3     4     7     6   7.0   6.0
# 4     5     8     6   NaN   NaN
