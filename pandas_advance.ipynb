# %%
import pandas as pd

# %%
# here  we have stored the data of this link in df named variable now wee can apply any operation on  this df 

df = pd.read_csv("https://www.stats.govt.nz/assets/Uploads/Annual-enterprise-survey/Annual-enterprise-survey-2021-financial-year-provisional/Download-data/annual-enterprise-survey-2021-financial-year-provisional-csv.csv")

# %%
# it shows the first five rows data if you want n rows data then pass that n into head method
df.head()
# Out:
#    Year Industry_aggregation_NZSIOC Industry_code_NZSIOC Industry_name_NZSIOC  \
# 0  2021                     Level 1                99999       All industries
# 1  2021                     Level 1                99999       All industries
# 2  2021                     Level 1                99999       All industries
# 3  2021                     Level 1                99999       All industries
# 4  2021                     Level 1                99999       All industries
#
#                 Units Variable_code  \
# 0  Dollars (millions)           H01
# 1  Dollars (millions)           H04
# 2  Dollars (millions)           H05
# 3  Dollars (millions)           H07
# 4  Dollars (millions)           H08
#
#                                      Variable_name      Variable_category  \
# 0                                     Total income  Financial performance
# 1  Sales, government funding, grants and subsidies  Financial performance
# ...

# %%
# it shows all columns as list
df.columns
# Out:
# Index(['Year', 'Industry_aggregation_NZSIOC', 'Industry_code_NZSIOC',
#        'Industry_name_NZSIOC', 'Units', 'Variable_code', 'Variable_name',
#        'Variable_category', 'Value', 'Industry_code_ANZSIC06'],
#       dtype='object')

# %%
# it will show the value of year column as series see the result
df['Year']
# Out:
# 0        2021
# 1        2021
# 2        2021
# 3        2021
# 4        2021
#          ...
# 41710    2013
# 41711    2013
# 41712    2013
# 41713    2013
# 41714    2013
# Name: Year, Length: 41715, dtype: int64

# %%
#  if  we want this year column data as a dataframe means in the form of row and column then apply
# an extra sqaure bracket see

df[['Year']]
# Out:
#        Year
# 0      2021
# 1      2021
# 2      2021
# 3      2021
# 4      2021
# ...     ...
# 41710  2013
# 41711  2013
# 41712  2013
# 41713  2013
# 41714  2013
#
# [41715 rows x 1 columns]

# %%
# the way we can get the multiple columns values as a dataframe
# if we remove one pair of square bracket then it will show an error because as series only one column,
# can get


# df['Year',Value']----- it will give an error so beloiw syntax is a correct way

df[['Year','Value']]
# Out:
#        Year    Value
# 0      2021  757,504
# 1      2021  674,890
# 2      2021   49,593
# 3      2021   33,020
# 4      2021  654,404
# ...     ...      ...
# 41710  2013       52
# 41711  2013       40
# 41712  2013       12
# 41713  2013        5
# 41714  2013       46
#
# [41715 rows x 2 columns]

# %%
# what if we want to get the data of a column/columns from one row to another row,
# suppose we want to fetch from 4th row to 8th row data of column see


df[['Year','Value']][4:9]
# Out:
#    Year    Value
# 4  2021  654,404
# 5  2021   26,138
# 6  2021    6,991
# 7  2021   27,801
# 8  2021  123,620

# %%
# we can get all column as series see and their datatype

df.dtypes
# Out:
# Year                            int64
# Industry_aggregation_NZSIOC    object
# Industry_code_NZSIOC           object
# Industry_name_NZSIOC           object
# Units                          object
# Variable_code                  object
# Variable_name                  object
# Variable_category              object
# Value                          object
# Industry_code_ANZSIC06         object
# dtype: object

# %%
# the way to get the columns as a series on the basis of a datatype mentioned as,
# see how we can do this 
# so the columns which have datatype "object" they got "True" their corresponding and which have,
# not they got false

df.dtypes == "object"
# Out:
# Year                           False
# Industry_aggregation_NZSIOC     True
# Industry_code_NZSIOC            True
# Industry_name_NZSIOC            True
# Units                           True
# Variable_code                   True
# Variable_name                   True
# Variable_category               True
# Value                           True
# Industry_code_ANZSIC06          True
# dtype: bool

# %%
# it will give only those columns which have datatype as object see below 
df.dtypes[df.dtypes == "object"]
# Out:
# Industry_aggregation_NZSIOC    object
# Industry_code_NZSIOC           object
# Industry_name_NZSIOC           object
# Units                          object
# Variable_code                  object
# Variable_name                  object
# Variable_category              object
# Value                          object
# Industry_code_ANZSIC06         object
# dtype: object

# %%
# it gonne convert the series of columns into a list

df.dtypes[df.dtypes == "object"].index
# Out:
# Index(['Industry_aggregation_NZSIOC', 'Industry_code_NZSIOC',
#        'Industry_name_NZSIOC', 'Units', 'Variable_code', 'Variable_name',
#        'Variable_category', 'Value', 'Industry_code_ANZSIC06'],
#       dtype='object')

# %%
it will give those columns data which have "object" datatype only

df[df.dtypes[df.dtypes == "object"].index]
# Out:
#       Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0                         Level 1                99999
# 1                         Level 1                99999
# 2                         Level 1                99999
# 3                         Level 1                99999
# 4                         Level 1                99999
# ...                           ...                  ...
# 41710                     Level 3                 ZZ11
# 41711                     Level 3                 ZZ11
# 41712                     Level 3                 ZZ11
# 41713                     Level 3                 ZZ11
# 41714                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# 2                  All industries  Dollars (millions)           H05
# ...

# %%
# how we can add new column to existing data "df" see

df["new_column"]=1

# %%
df
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2021                     Level 1                99999
# 1      2021                     Level 1                99999
# 2      2021                     Level 1                99999
# 3      2021                     Level 1                99999
# 4      2021                     Level 1                99999
# ...     ...                         ...                  ...
# 41710  2013                     Level 3                 ZZ11
# 41711  2013                     Level 3                 ZZ11
# 41712  2013                     Level 3                 ZZ11
# 41713  2013                     Level 3                 ZZ11
# 41714  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
df["new_column1"]=int(df["Year"]) + int(df["Value"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 df["new_column1"]=int(df["Year"]) + int(df["Value"])
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/series.py:206, in _coerce_method.<locals>.wrapper(self)
#     204 if len(self) == 1:
#     205     return converter(self.iloc[0])
# --> 206 raise TypeError(f"cannot convert the series to {converter}")
#
# TypeError: cannot convert the series to <class 'int'>

# %%
# IT WILL SHOWS THE UNIQUE VALUES OF YEAR COLUMN AND LENGTH OF COLUMN 

pd.Categorical(df['Year'])
# Out:
# [2021, 2021, 2021, 2021, 2021, ..., 2013, 2013, 2013, 2013, 2013]
# Length: 41715
# Categories (9, int64): [2013, 2014, 2015, 2016, ..., 2018, 2019, 2020, 2021]

# %%
# SUPPOSE WE WANT DATA IN A CASE WHERE VALUE OF YEAR COLUMN > 2015 SEE

df[df['Year']>2015]
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2021                     Level 1                99999
# 1      2021                     Level 1                99999
# 2      2021                     Level 1                99999
# 3      2021                     Level 1                99999
# 4      2021                     Level 1                99999
# ...     ...                         ...                  ...
# 27805  2016                     Level 3                 ZZ11
# 27806  2016                     Level 3                 ZZ11
# 27807  2016                     Level 3                 ZZ11
# 27808  2016                     Level 3                 ZZ11
# 27809  2016                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
# it will give from  0 to 1 rows only 

df[0:2]
# Out:
#    Year Industry_aggregation_NZSIOC Industry_code_NZSIOC Industry_name_NZSIOC  \
# 0  2021                     Level 1                99999       All industries
# 1  2021                     Level 1                99999       All industries
#
#                 Units Variable_code  \
# 0  Dollars (millions)           H01
# 1  Dollars (millions)           H04
#
#                                      Variable_name      Variable_category  \
# 0                                     Total income  Financial performance
# 1  Sales, government funding, grants and subsidies  Financial performance
#
#      Value                             Industry_code_ANZSIC06  new_column
# 0  757,504  ANZSIC06 divisions A-S (excluding classes K633...           1
# 1  674,890  ANZSIC06 divisions A-S (excluding classes K633...           1

# %%
# mtlb column year and value ka wah data jo row 0 and 1 me hai wahi lana hai

df[['Year','Units']][0:2]
# Out:
#    Year               Units
# 0  2021  Dollars (millions)
# 1  2021  Dollars (millions)

# %%
# df[0:2] equivalent to df.iloc[0:2] so 

df.iloc[0:2]
# Out:
#    Year Industry_aggregation_NZSIOC Industry_code_NZSIOC Industry_name_NZSIOC  \
# 0  2021                     Level 1                99999       All industries
# 1  2021                     Level 1                99999       All industries
#
#                 Units Variable_code  \
# 0  Dollars (millions)           H01
# 1  Dollars (millions)           H04
#
#                                      Variable_name      Variable_category  \
# 0                                     Total income  Financial performance
# 1  Sales, government funding, grants and subsidies  Financial performance
#
#      Value                             Industry_code_ANZSIC06  new_column
# 0  757,504  ANZSIC06 divisions A-S (excluding classes K633...           1
# 1  674,890  ANZSIC06 divisions A-S (excluding classes K633...           1

# %%
df.iloc[0:2]['Year','Value']
# facing this erroe bkoz df.iloc take inbuilt index so see next column
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexes/base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File /opt/conda/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/conda/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Year', 'Value')
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df.loc[0:2,['Year','Value']]
# mtlb 0 se lekar row 2 tak ka data fo yeara and value column
# Out:
#    Year    Value
# 0  2021  757,504
# 1  2021  674,890
# 2  2021   49,593

# %%
df.iloc[0:2][0:1:2]
# Out:
#    Year Industry_aggregation_NZSIOC Industry_code_NZSIOC Industry_name_NZSIOC  \
# 0  2021                     Level 1                99999       All industries
#
#                 Units Variable_code Variable_name      Variable_category  \
# 0  Dollars (millions)           H01  Total income  Financial performance
#
#      Value                             Industry_code_ANZSIC06  new_column
# 0  757,504  ANZSIC06 divisions A-S (excluding classes K633...           1
